# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
school_data_to_load = Path("Resources/schools_complete.csv")
student_data_to_load = Path("Resources/students_complete.csv")

# Read School and Student Data File and store into Pandas DataFrames
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete_df = pd.merge(student_data_df, school_data_df, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## Local Government Area Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average maths score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing maths score (50 or greater)
#
# * Calculate the percentage of students with a passing reading score (50 or greater)
#
# * Calculate the percentage of students who passed maths **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Calculate the total number of schools
total_schools = len(school_data_df['School ID'].unique())

#Calculate the total number of students
total_students = len(student_data_df['Student ID'].unique())

#Calculate the total budget
total_budget = school_data_df['budget'].sum()

#Calculate the average maths score
avg_maths_score = student_data_df['maths_score'].mean()

#Calculate the average reading score
avg_reading_score = student_data_df['reading_score'].mean()

#Calculate the percentage of students with a passing maths score (50 or greater)
maths_score = student_data_df.loc[student_data_df['maths_score']>=50]['maths_score'].count()
maths_pass_percentage = maths_score/total_students

#Calculate the percentage of students with a passing reading score (50 or greater)
reading_score = student_data_df.loc[student_data_df['reading_score']>=50]['reading_score'].count()
reading_score_pass_percentage = reading_score/total_students

#Calculate the percentage of students who passed maths **and** reading (% Overall Passing)
overall_passing = student_data_df[(student_data_df['maths_score'] >= 50) & (student_data_df['reading_score'] >= 50)]['student_name'].count()
overall_passing_percenatage= overall_passing/total_students

#DataFrame to hold the above results
local_gov_area_summary_df = pd.DataFrame({ 
                                            "Total Schools": [total_schools],
                                            "Total Students": [total_students],
                                            "Total Budget": [total_budget],
                                            "Average Maths Score": [avg_maths_score],
                                            "Average Reading Score": [avg_reading_score],
                                            "% Passing Maths": [maths_pass_percentage], 
                                            "% Passing Reading":[reading_score_pass_percentage],                                           
                                            "Overall Passing Rate": [overall_passing_percenatage] 
                                        })

#Format the data into readable from the above DataFrame
print("                                                Local Government Area Summary                                       ")
local_gov_area_summary_df.style.format({"Total Budget": "${:,.2f}",
                                        "Average Reading Score": "{:.1f}", 
                                        "Average Maths Score": "{:.1f}",
                                        "% Passing Maths": "{:.2%}",
                                        "% Passing Reading":"{:.2%}",
                                        "Overall Passing Rate": "{:.2%}"
                                      })
# Out:
#                                                 Local Government Area Summary
# <style type="text/css">
# </style>
# <table id="T_41e70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41e70_level0_col0" class="col_heading level0 col0" >Total Schools</th>
#       <th id="T_41e70_level0_col1" class="col_heading level0 col1" >Total Students</th>
#       <th id="T_41e70_level0_col2" class="col_heading level0 col2" >Total Budget</th>
#       <th id="T_41e70_level0_col3" class="col_heading level0 col3" >Average Maths Score</th>
#       <th id="T_41e70_level0_col4" class="col_heading level0 col4" >Average Reading Score</th>
#       <th id="T_41e70_level0_col5" class="col_heading level0 col5" >% Passing Maths</th>
#       <th id="T_41e70_level0_col6" class="col_heading level0 col6" >% Passing Reading</th>
#       <th id="T_41e70_level0_col7" class="col_heading level0 col7" >Overall Passing Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41e70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41e70_row0_col0" class="data row0 col0" >15</td>
#       <td id="T_41e70_row0_col1" class="data row0 col1" >39170</td>
#       <td id="T_41e70_row0_col2" class="data row0 col2" >$24,649,428.00</td>
#       <td id="T_41e70_row0_col3" class="data row0 col3" >70.3</td>
#       <td id="T_41e70_row0_col4" class="data row0 col4" >70.0</td>
#       <td id="T_41e70_row0_col5" class="data row0 col5" >86.08%</td>
#       <td id="T_41e70_row0_col6" class="data row0 col6" >84.43%</td>
#       <td id="T_41e70_row0_col7" class="data row0 col7" >72.81%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarises key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed maths **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#set indexby School Name
school_data_complete_df=school_data_complete_df.set_index('school_name')
#group by School Name
school_name=school_data_complete_df.groupby(["school_name"])
school_data_complete_df

# print(school_data_complete_df.groupby(['school_name']))

#school_data_complete_df.head()
# school_name = school_data_complete_df.groupby('school_name')


#print(school_data_complete_df.groupby('school_name'))

# #School type with index school name
# school_type = school_data_df.set_index('type')

# #Total Students
# total_students =school_name['Student ID'].count()

# #Total School Budget with index school name
# total_school_budget = school_data_df.set_index('budget')

# #Per Student Budget with index school name
# budget_per_student = school_data_df.set_index('budget')/ school_data_df.set_index('size')

# #Average Maths Score
# avg_maths_scr = school_name['maths_score'].mean()

# #Average Reading Score
# avg_reading_scr = school_name['reading_score'].mean()

# #% Passing Maths with index school name
# maths_pass_percent =  school_data_complete_df[school_data_complete_df['maths_score']>=50].groupby('Student ID').count()/total_students

# #% Passing Reading with index school name
# reading_score_percent = school_data_complete_df[school_data_complete_df['reading_score']>=50].groupby('Student ID').count()/total_students

# #% Overall Passing with index school name
# overall_pass_percent =  school_data_complete_df[(school_data_complete_df['maths_score']>=50) & (school_data_complete_df['reading_score']>=50)].groupby('Student ID').count()/total_students

# school_summary_df = pd.DataFrame({
#                                     "School Type": school_type,
#                                     "Total Students": total_students,
#                                     "Total School Budget": total_school_budget,
#                                     "Per Student Budget": budget_per_student,                                   
#                                     "Average Maths Score": avg_maths_scr,
#                                     "Average Reading Score": avg_reading_scr,
#                                     "% Passing Maths": maths_pass_percent,
#                                     "% Passing Reading": reading_score_percent,
#                                     "Overall Passing Rate": overall_pass_percent
#                                 })

# #Format the data into readable from the above DataFrame
# print("                                                School Summary                                                      ")
# school_summary_df.style.format({"Total School Budget": "${:,.2f}",
#                                 "Per Student Budget": "${:.0f}",
#                                 "Average Maths Score": "{:.1f}",
#                                 "Average Reading Score": "{:.1f}", 
#                                 "% Passing Maths": "{:.2%}",
#                                 "% Passing Reading":"{:.2%}",
#                                 "Overall Passing Rate": "{:.2%}"
#                               })
# Out:
#                     Student ID     student_name gender  year  reading_score  \
# school_name
# Huang High School            0     Paul Bradley      M     9             96
# Huang High School            1     Victor Smith      M    12             90
# Huang High School            2  Kevin Rodriguez      M    12             41
# Huang High School            3    Richard Scott      M    12             89
# Huang High School            4       Bonnie Ray      F     9             87
# ...                        ...              ...    ...   ...            ...
# Thomas High School       39165     Donna Howard      F    12             51
# Thomas High School       39166        Dawn Bell      F    10             81
# Thomas High School       39167   Rebecca Tanner      F     9             99
# Thomas High School       39168     Desiree Kidd      F    10             72
# Thomas High School       39169  Carolyn Jackson      F    11             47
#
#                     maths_score  School ID         type  size   budget
# school_name
# Huang High School            94          0   Government  2917  1910635
# Huang High School            43          0   Government  2917  1910635
# Huang High School            76          0   Government  2917  1910635
# Huang High School            86          0   Government  2917  1910635
# Huang High School            69          0   Government  2917  1910635
# ...                         ...        ...          ...   ...      ...
# Thomas High School           48         14  Independent  1635  1043130
# Thomas High School           89         14  Independent  1635  1043130
# Thomas High School           99         14  Independent  1635  1043130
# Thomas High School           77         14  Independent  1635  1043130
# Thomas High School           62         14  Independent  1635  1043130
#
# [39170 rows x 10 columns]

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
#sorting %overallpassing by descending from the school_summary dataframe
sorted_overall_pass = school_summary_df.sort_values("Overall Passing Rate", ascending = False)
sorted_overall_pass.style.format({"Total School Budget": "${:,.2f}",
                                "Per Student Budget": "${:.0f}",
                                "Average Maths Score": "{:.1f}",
                                "Average Reading Score": "{:.1f}", 
                                "% Passing Maths": "{:.2%}",
                                "% Passing Reading":"{:.2%}",
                                "Overall Passing Rate": "{:.2%}"
                           })
# Out:
# <style type="text/css">
# </style>
# <table id="T_1f30f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >School Type</th>
#       <th class="col_heading level0 col1" >Total Students</th>
#       <th class="col_heading level0 col2" >Total School Budget</th>
#       <th class="col_heading level0 col3" >Per Student Budget</th>
#       <th class="col_heading level0 col4" >Average Maths Score</th>
#       <th class="col_heading level0 col5" >Average Reading Score</th>
#       <th class="col_heading level0 col6" >% Passing Maths</th>
#       <th class="col_heading level0 col7" >% Passing Reading</th>
#       <th class="col_heading level0 col8" >Overall Passing Rate</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f30f_level0_row0" class="row_heading level0 row0" >Griffin High School</th>
#       <td id="T_1f30f_row0_col0" class="data row0 col0" >Independent</td>
#       <td id="T_1f30f_row0_col1" class="data row0 col1" >1468</td>
#       <td id="T_1f30f_row0_col2" class="data row0 col2" >$917,500.00</td>
#       <td id="T_1f30f_row0_col3" class="data row0 col3" >$625</td>
#       <td id="T_1f30f_row0_col4" class="data row0 col4" >71.8</td>
#       <td id="T_1f30f_row0_col5" class="data row0 col5" >71.2</td>
#       <td id="T_1f30f_row0_col6" class="data row0 col6" >91.21%</td>
#       <td id="T_1f30f_row0_col7" class="data row0 col7" >88.49%</td>
#       <td id="T_1f30f_row0_col8" class="data row0 col8" >81.34%</td>
#     </tr>
#     <tr>
#       <th id="T_1f30f_level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#       <td id="T_1f30f_row1_col0" class="data row1 col0" >Independent</td>
#       <td id="T_1f30f_row1_col1" class="data row1 col1" >1858</td>
#       <td id="T_1f30f_row1_col2" class="data row1 col2" >$1,081,356.00</td>
#       <td id="T_1f30f_row1_col3" class="data row1 col3" >$582</td>
#       <td id="T_1f30f_row1_col4" class="data row1 col4" >71.7</td>
#       <td id="T_1f30f_row1_col5" class="data row1 col5" >71.4</td>
#       <td id="T_1f30f_row1_col6" class="data row1 col6" >90.85%</td>
#       <td id="T_1f30f_row1_col7" class="data row1 col7" >89.07%</td>
#       <td id="T_1f30f_row1_col8" class="data row1 col8" >80.79%</td>
#     </tr>
#     <tr>
#       <th id="T_1f30f_level0_row2" class="row_heading level0 row2" >Bailey High School</th>
#       <td id="T_1f30f_row2_col0" class="data row2 col0" >Government</td>
#       <td id="T_1f30f_row2_col1" class="data row2 col1" >4976</td>
#       <td id="T_1f30f_row2_col2" class="data row2 col2" >$3,124,928.00</td>
#       <td id="T_1f30f_row2_col3" class="data row2 col3" >$628</td>
#       <td id="T_1f30f_row2_col4" class="data row2 col4" >72.4</td>
#       <td id="T_1f30f_row2_col5" class="data row2 col5" >71.0</td>
#       <td id="T_1f30f_row2_col6" class="data row2 col6" >91.64%</td>
#       <td id="T_1f30f_row2_col7" class="data row2 col7" >87.38%</td>
#       <td id="T_1f30f_row2_col8" class="data row2 col8" >80.08%</td>
#     </tr>
#     <tr>
#       <th id="T_1f30f_level0_row3" class="row_heading level0 row3" >Wright High School</th>
#       <td id="T_1f30f_row3_col0" class="data row3 col0" >Independent</td>
#       <td id="T_1f30f_row3_col1" class="data row3 col1" >1800</td>
#       <td id="T_1f30f_row3_col2" class="data row3 col2" >$1,049,400.00</td>
#       <td id="T_1f30f_row3_col3" class="data row3 col3" >$583</td>
#       <td id="T_1f30f_row3_col4" class="data row3 col4" >72.0</td>
#       <td id="T_1f30f_row3_col5" class="data row3 col5" >71.0</td>
#       <td id="T_1f30f_row3_col6" class="data row3 col6" >91.78%</td>
#       <td id="T_1f30f_row3_col7" class="data row3 col7" >86.67%</td>
#       <td id="T_1f30f_row3_col8" class="data row3 col8" >79.72%</td>
#     </tr>
#     <tr>
#       <th id="T_1f30f_level0_row4" class="row_heading level0 row4" >Rodriguez High School</th>
#       <td id="T_1f30f_row4_col0" class="data row4 col0" >Government</td>
#       <td id="T_1f30f_row4_col1" class="data row4 col1" >3999</td>
#       <td id="T_1f30f_row4_col2" class="data row4 col2" >$2,547,363.00</td>
#       <td id="T_1f30f_row4_col3" class="data row4 col3" >$637</td>
#       <td id="T_1f30f_row4_col4" class="data row4 col4" >72.0</td>
#       <td id="T_1f30f_row4_col5" class="data row4 col5" >70.9</td>
#       <td id="T_1f30f_row4_col6" class="data row4 col6" >90.80%</td>
#       <td id="T_1f30f_row4_col7" class="data row4 col7" >87.40%</td>
#       <td id="T_1f30f_row4_col8" class="data row4 col8" >79.42%</td>
#     </tr>
#     <tr>
#       <th id="T_1f30f_level0_row5" class="row_heading level0 row5" >Pena High School</th>
#       <td id="T_1f30f_row5_col0" class="data row5 col0" >Independent</td>
#       <td id="T_1f30f_row5_col1" class="data row5 col1" >962</td>
#       <td id="T_1f30f_row5_col2" class="data row5 col2" >$585,858.00</td>
#       <td id="T_1f30f_row5_col3" class="data row5 col3" >$609</td>
#       <td id="T_1f30f_row5_col4" class="data row5 col4" >72.1</td>
#       <td id="T_1f30f_row5_col5" class="data row5 col5" >71.6</td>
#       <td id="T_1f30f_row5_col6" class="data row5 col6" >91.68%</td>
#       <td id="T_1f30f_row5_col7" class="data row5 col7" >86.59%</td>
#       <td id="T_1f30f_row5_col8" class="data row5 col8" >79.21%</td>
#     </tr>
#     <tr>
#       <th id="T_1f30f_level0_row6" class="row_heading level0 row6" >Holden High School</th>
#       <td id="T_1f30f_row6_col0" class="data row6 col0" >Independent</td>
#       <td id="T_1f30f_row6_col1" class="data row6 col1" >427</td>
#       <td id="T_1f30f_row6_col2" class="data row6 col2" >$248,087.00</td>
#       <td id="T_1f30f_row6_col3" class="data row6 col3" >$581</td>
#       <td id="T_1f30f_row6_col4" class="data row6 col4" >72.6</td>
#       <td id="T_1f30f_row6_col5" class="data row6 col5" >71.7</td>
#       <td id="T_1f30f_row6_col6" class="data row6 col6" >89.93%</td>
#       <td id="T_1f30f_row6_col7" class="data row6 col7" >88.52%</td>
#       <td id="T_1f30f_row6_col8" class="data row6 col8" >78.92%</td>
#     </tr>
#     <tr>
#       <th id="T_1f30f_level0_row7" class="row_heading level0 row7" >Shelton High School</th>
#       <td id="T_1f30f_row7_col0" class="data row7 col0" >Independent</td>
#       <td id="T_1f30f_row7_col1" class="data row7 col1" >1761</td>
#       <td id="T_1f30f_row7_col2" class="data row7 col2" >$1,056,600.00</td>
#       <td id="T_1f30f_row7_col3" class="data row7 col3" >$600</td>
#       <td id="T_1f30f_row7_col4" class="data row7 col4" >72.0</td>
#       <td id="T_1f30f_row7_col5" class="data row7 col5" >70.3</td>
#       <td id="T_1f30f_row7_col6" class="data row7 col6" >91.54%</td>
#       <td id="T_1f30f_row7_col7" class="data row7 col7" >86.71%</td>
#       <td id="T_1f30f_row7_col8" class="data row7 col8" >78.88%</td>
#     </tr>
#     <tr>
#       <th id="T_1f30f_level0_row8" class="row_heading level0 row8" >Thomas High School</th>
#       <td id="T_1f30f_row8_col0" class="data row8 col0" >Independent</td>
#       <td id="T_1f30f_row8_col1" class="data row8 col1" >1635</td>
#       <td id="T_1f30f_row8_col2" class="data row8 col2" >$1,043,130.00</td>
#       <td id="T_1f30f_row8_col3" class="data row8 col3" >$638</td>
#       <td id="T_1f30f_row8_col4" class="data row8 col4" >69.6</td>
#       <td id="T_1f30f_row8_col5" class="data row8 col5" >69.8</td>
#       <td id="T_1f30f_row8_col6" class="data row8 col6" >83.85%</td>
#       <td id="T_1f30f_row8_col7" class="data row8 col7" >82.63%</td>
#       <td id="T_1f30f_row8_col8" class="data row8 col8" >69.48%</td>
#     </tr>
#     <tr>
#       <th id="T_1f30f_level0_row9" class="row_heading level0 row9" >Figueroa High School</th>
#       <td id="T_1f30f_row9_col0" class="data row9 col0" >Government</td>
#       <td i

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
#sorting %overallpassing by ascending for worst performing schools
sort_bottom_pass_schools = school_summary_df.sort_values('Overall Passing Rate',ascending=True)
sort_bottom_pass_schools.style.format({"Total School Budget": "${:,.2f}",
                                       "Per Student Budget": "${:.0f}",
                                       "Average Maths Score": "{:.1f}",
                                       "Average Reading Score": "{:.1f}", 
                                       "% Passing Maths": "{:.2%}",
                                       "% Passing Reading":"{:.2%}",
                                       "Overall Passing Rate": "{:.2%}"
                                     })
# Out:
# <style type="text/css">
# </style>
# <table id="T_45d18_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >School Type</th>
#       <th class="col_heading level0 col1" >Total Students</th>
#       <th class="col_heading level0 col2" >Total School Budget</th>
#       <th class="col_heading level0 col3" >Per Student Budget</th>
#       <th class="col_heading level0 col4" >Average Maths Score</th>
#       <th class="col_heading level0 col5" >Average Reading Score</th>
#       <th class="col_heading level0 col6" >% Passing Maths</th>
#       <th class="col_heading level0 col7" >% Passing Reading</th>
#       <th class="col_heading level0 col8" >Overall Passing Rate</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45d18_level0_row0" class="row_heading level0 row0" >Hernandez High School</th>
#       <td id="T_45d18_row0_col0" class="data row0 col0" >Government</td>
#       <td id="T_45d18_row0_col1" class="data row0 col1" >4635</td>
#       <td id="T_45d18_row0_col2" class="data row0 col2" >$3,022,020.00</td>
#       <td id="T_45d18_row0_col3" class="data row0 col3" >$652</td>
#       <td id="T_45d18_row0_col4" class="data row0 col4" >68.9</td>
#       <td id="T_45d18_row0_col5" class="data row0 col5" >69.2</td>
#       <td id="T_45d18_row0_col6" class="data row0 col6" >80.95%</td>
#       <td id="T_45d18_row0_col7" class="data row0 col7" >81.88%</td>
#       <td id="T_45d18_row0_col8" class="data row0 col8" >66.36%</td>
#     </tr>
#     <tr>
#       <th id="T_45d18_level0_
</td>
#     </tr>
#     <tr>
#       <th id="T_45d18_level0_row6" class="row_heading level0 row6" >Thomas High School</th>
#       <td id="T_45d18_row6_col0" class="data row6 col0" >Independent</td>
#       <td id="T_45d18_row6_col1" class="data row6 col1" >1635</td>
#       <td id="T_45d18_row6_col2" class="data row6 col2" >$1,043,130.00</td>
#       <td id="T_45d18_row6_col3" class="data row6 col3" >$638</td>
#       <td id="T_45d18_row6_col4" class="data row6 col4" >69.6</td>
#       <td id="T_45d18_row6_col5" class="data row6 col5" >69.8</td>
#       <td id="T_45d18_row6_col6" class="data row6 col6" >83.85%</td>
#       <td id="T_45d18_row6_col7" class="data row6 col7" >82.63%</td>
#       <td id="T_45d18_row6_col8" class="data row6 col8" >69.48%</td>
#     </tr>
#     <tr>
#       <th id="T_45d18_level0_row7" class="row_heading level0 row7" >Shelton High School</th>
#       <td id="T_45d18_row7_col0" class="data row7 col0" >Independent</td>
#       <td id="T_45d18_row7_col1" class="data row7 col1" >1761</td>
#       <td id="T_45d18_row7_col2" class="data row7 col2" >$1,056,600.00</td>
#       <td id="T_45d18_row7_col3" class="data row7 col3" >$600</td>
#       <td id="T_45d18_row7_col4" class="data row7 col4" >72.0</td>
#       <td id="T_45d18_row7_col5" class="data row7 col5" >70.3</td>
#       <td id="T_45d18_row7_col6" class="data row7 col6" >91.54%</td>
#       <td id="T_45d18_row7_col7" class="data row7 col7" >86.71%</td>
#       <td id="T_45d18_row7_col8" class="data row7 col8" >78.88%</td>
#     </tr>
#     <tr>
#       <th id="T_45d18_level0_row8" class="row_heading level0 row8" >Holden High School</th>
#       <td id="T_45d18_row8_col0" class="data row8 col0" >Independent</td>
#       <td id="T_45d18_row8_col1" class="data row8 col1" >427</td>
#       <td id="T_45d18_row8_col2" class="data row8 col2" >$248,087.00</td>
#       <td id="T_45d18_row8_col3" class="data row8 col3" >$581</td>
#       <td id="T_45d18_row8_col4" class="data row8 col4" >72.6</td>
#       <td id="T_45d18_row8_col5" class="data row8 col5" >71.7</td>
#       <td id="T_45d18_row8_col6" class="data row8 col6" >89.93%</td>
#       <td id="T_45d18_row8_col7" class="data row8 col7" >88.52%</td>
#       <td id="T_45d18_row8_col8" class="data row8 col8" >78.92%</td>
#     </tr>
#     <tr>
#       <th id="T_45d18_level0_row9" class="row_heading level0 row9" >Pena High School</th>
#       <td id="T_45d18_row9_col0" class="data row9 col0" >Independent</td>
#       <td id

# %% [markdown]
# ## Maths Scores by Year

# %% [markdown]
# * Create a table that lists the average maths score for students of each year level (9, 10, 11, 12) at each school.
#
#   * Create a pandas series for each year. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#group by math scores by years for each school 
year_9=student_data_df.loc[student_data_df['year']==9].groupby('school_name')['maths_score'].mean()
year_10=student_data_df.loc[student_data_df['year']==10].groupby('school_name')['maths_score'].mean()
year_11=student_data_df.loc[student_data_df['year']==11].groupby('school_name')['maths_score'].mean()
year_12=student_data_df.loc[student_data_df['year']==12].groupby('school_name')['maths_score'].mean()

maths_scors_by_year_df =pd.DataFrame({
                                      "Year 9": year_9,
                                      "Year 10": year_10,
                                      "Year 11": year_11,
                                      "Year 12": year_12
                                    })

maths_scors_by_year_df.style.format({
                                     "Year 9": "${:,.1f}",
                                     "Year 10": "${:,.1f}",
                                     "Year 11": "${:,.1f}",
                                     "Year 12": "${:,.1f}",
                                     })
# Out:
# <style type="text/css">
# </style>
# <table id="T_9b5c4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >
td>
#     </tr>
#     <tr>
#       <th id="T_9b5c4_level0_row10" class="row_heading level0 row10" >Rodriguez High School</th>
#       <td id="T_9b5c4_row10_col0" class="data row10 col0" >$71.9</td>
#       <td id="T_9b5c4_row10_col1" class="data row10 col1" >$71.8</td>
#       <td id="T_9b5c4_row10_col2" class="data row10 col2" >$72.4</td>
#       <td id="T_9b5c4_row10_col3" class="data row10 col3" >$72.2</td>
#     </tr>
#     <tr>
#       <th id="T_9b5c4_level0_row11" class="row_heading level0 row11" >Shelton High School</th>
#       <td id="T_9b5c4_row11_col0" class="data row11 col0" >$72.9</td>
#       <td id="T_9b5c4_row11_col1" class="data row11 col1" >$72.5</td>
#       <td id="T_9b5c4_row11_col2" class="data row11 col2" >$70.1</td>
#       <td id="T_9b5c4_row11_col3" class="data row11 col3" >$72.3</td>
#     </tr>
#     <tr>
#       <th id="T_9b5c4_level0_row12" class="row_heading level0 row12" >Thomas High School</th>
#       <td id="T_9b5c4_row12_col0" class="data row12 col0" >$69.2</td>
#       <td id="T_9b5c4_row12_col1" class="data row12 col1" >$70.1</td>
#       <td id="T_9b5c4_row12_col2" class="data row12 col2" >$69.7</td>
#       <td id="T_9b5c4_row12_col3" class="data row12 col3" >$69.4</td>
#     </tr>
#     <tr>
#       <th id="T_9b5c4_level0_row13" class="row_heading level0 row13" >Wilson High School</th>
#       <td id="T_9b5c4_row13_col0" class="data row13 col0" >$69.2</td>
#       <td id="T_9b5c4_row13_col1" class="data row13 col1" >$69.5</td>
#       <td id="T_9b5c4_row13_col2" class="data row13 col2" >$68.4</td>
#       <td id="T_9b5c4_row13_col3" class="data row13 col3" >$69.8</td>
#     </tr>
#     <tr>
#       <th id="T_9b5c4_level0_row14" class="row_heading level0 row14" >Wright High School</th>
#       <td id="T_9b5c4_row14_col0" class="data row14 col0" >$71.7</td>
#       <td id="T_9b5c4_row14_col1" class="data row14 col1" >$72.2</td>
#       <td id="T_9b5c4_row14_col2" class="data row14 col2" >$73.3</td>
#       <td id="T_9b5c4_row14_col3" class="data row14 col3" >$70.8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Reading Score by Year

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#group by reading_score by years for each school 
year_9=student_data_df.loc[student_data_df['year']==9].groupby('school_name')['reading_score'].mean()
year_10=student_data_df.loc[student_data_df['year']==10].groupby('school_name')['reading_score'].mean()
year_11=student_data_df.loc[student_data_df['year']==11].groupby('school_name')['reading_score'].mean()
year_12=student_data_df.loc[student_data_df['year']==12].groupby('school_name')['reading_score'].mean()

maths_scors_by_year_df =pd.DataFrame({
                                      "Year 9": year_9,
                                      "Year 10": year_10,
                                      "Year 11": year_11,
                                      "Year 12": year_12
                                    })

maths_scors_by_year_df.style.format({
                                     "Year 9": "${:,.1f}",
                                     "Year 10": "${:,.1f}",
                                     "Year 11": "${:,.1f}",
                                     "Year 12": "${:,.1f}",
                                     })
# Out:
# <style type="text/css">
# </style>
# <table id="T_9f311_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year 9</th>
#       <th class="col_heading level0 col1" >Year 10</th>
#       <th class="col_heading level0 col2" >Year 11</th>
#       <th class="col_heading level0 col3" >Year 12</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f311_level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#       <td id="T_9f311_row0_col0" class="data row0 col0" >$70.9</td>
#       <td id="T_9f311_row0_col1" class="data row0 col1" >$70.8</td>
#       <td id="T_9f311_row0_col2" class="data row0 col2" >$70.3</td>
#       <td id="T_9f311_row0_col3" class="data row0 col3" >$72.2</td>
#     </tr>
#     <tr>
#       <th id="T_9f311_level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#       <td id="T_9f311_row1_col0" class="data row1 col0" >$71.2</td>
#       <td id="T_9f311_row1_col1" class="data row1 col1" >$71.3</td>
#       <td id="T_9f311_row1_col2" class="data row1 col2" >$71.2</td>
#       <td id="T_9f311_row1_col3" class="data row1 col3" >$71.9</td>
#     </tr>
#     <tr>
#       <th id="T_9f311_level0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_9f311_level0_row13" class="row_heading level0 row13" >Wilson High School</th>
#       <td id="T_9f311_row13_col0" class="data row13 col0" >$68.7</td>
#       <td id="T_9f311_row13_col1" class="data row13 col1" >$68.4</td>
#       <td id="T_9f311_row13_col2" class="data row13 col2" >$68.8</td>
#       <td id="T_9f311_row13_col3" class="data row13 col3" >$69.9</td>
#     </tr>
#     <tr>
#       <th id="T_9f311_level0_row14" class="row_heading level0 row14" >Wright High School</th>
#       <td id="T_9f311_row14_col0" class="data row14 col0" >$71.8</td>
#       <td id="T_9f311_row14_col1" class="data row14 col1" >$71.4</td>
#       <td id="T_9f311_row14_col2" class="data row14 col2" >$70.5</td>
#       <td id="T_9f311_row14_col3" class="data row14 col3" >$69.8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Create the bins in which Data will be held
#bins = [0,584, 630, 645, 1000000]
group_name = ['< $585', "$585 - 630", "$630 - 645", "$645-680"]
school_data_complete_df['spending_bin'] = pd.cut(school_data_complete_df['budget']/school_data_complete_df['size'], bins, labels = group_name, include_lowest=True)

school_data_complete_df
#group by spending
#spending_range = school_data_complete_df.groupby('binned')
# Out:
#        Student ID     student_name gender  year         school_name  \
# 0               0     Paul Bradley      M     9   Huang High School
# 1               1     Victor Smith      M    12   Huang High School
# 2               2  Kevin Rodriguez      M    12   Huang High School
# 3               3    Richard Scott      M    12   Huang High School
# 4               4       Bonnie Ray      F     9   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F    12  Thomas High School
# 39166       39166        Dawn Bell      F    10  Thomas High School
# 39167       39167   Rebecca Tanner      F     9  Thomas High School
# 39168       39168     Desiree Kidd      F    10  Thomas High School
# 39169       39169  Carolyn Jackson      F    11  Thomas High School
#
#        reading_score  maths_score  School ID         type  size   budget  \
# 0                 96           94          0   Government  2917  1910635
# 1                 90           43          0   Government  2917  1910635
# 2                 41           76          0   Government  2917  1910635
# 3                 89           86          0   Government  2917  1910635
# 4                 87           69          0   Government  2917  1910635
# ...              ...          ...        ...          ...   ...      ...
# 39165             51           48         14  Independent  1635  1043130
# 39166             81           89         14  Independent  1635  1043130
# 39167             99           99         14  Independent  1635  1043130
# 39168             72           77         14  Independent  1635  1043130
# 39169             47           62         14  Independent  1635  1043130
#
#       spending_bin
# 0         $645-680
# 1         $645-680
# 2         $645-680
# 3         $645-680
# 4         $645-680
# ...            ...
# 39165   $630 - 645
# 39166   $630 - 645
# 39167   $630 - 645
# 39168   $630 - 645
# 39169   $630 - 645
#
# [39170 rows x 12 columns]

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Out:
#                     Average Maths Score  Average Reading Score  \
# School Size
# Small (<1000)                 72.335748              71.636864
# Medium (1000-2000)            71.421650              70.720164
# Large (2000-5000)             69.751809              69.576052
#
#                     % Passing Maths  % Passing Reading  % Overall Passing
# School Size
# Small (<1000)             90.806867          87.557513          79.066348
# Medium (1000-2000)        89.846560          86.714149          78.039785
# Large (2000-5000)         84.252804          83.301185          70.293507

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Out:
#              Average Maths Score  Average Reading Score  % Passing Maths  \
# School Type
# Government             69.834806              69.675929        84.462375
# Independent            71.368822              70.718933        89.204043
#
#              % Passing Reading  % Overall Passing
# School Type
# Government           83.587562          70.698993
# Independent          86.247789          76.973340
